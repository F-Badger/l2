# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pdmarks = pd.read_csv('student_marks.csv')
pdmarks
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology
# 0    John      M  05/04/1988     55       45         56       87       21
# 1     Tom      M  04/05/1987     75       96         78       64       90
# 2    Bill      M  25/05/1989     25       54         89       76       95
# 3   Carol      F  12/08/1990     78       96         86       63       54
# 4    Jane      F  02/09/1989     58       96         78       46       96
# 5    Annu      F  05/04/1988     45       87         52       89       55
# 6   Peter      F  04/05/1987     55       64         61       58       75
# 7  Ritesh      M  25/05/1989     54       76         87       56       25
# 8   Farha      F  12/08/1990     55       63         89       75       78
# 9    Mike      M  02/09/1989     96       46         77       83       58

# %%
sns.scatterplot(data=pdmarks,x='Name',y='Chemistry')
# Out:
# <AxesSubplot: xlabel='Name', ylabel='Chemistry'>

# %%
clusterdict={     'Maths': [80,80,80,80,60,60,60,60],
              'Chemistry': [70,70,70,70,90,90,90,90]  }
pdcluster=pd.DataFrame(clusterdict)
pdcluster
# Out:
#    Maths  Chemistry
# 0     80         70
# 1     80         70
# 2     80         70
# 3     80         70
# 4     60         90
# 5     60         90
# 6     60         90
# 7     60         90

# %%
sns.scatterplot(data=pdcluster,x='Maths',y='Chemistry')
# Out:
# <AxesSubplot: xlabel='Maths', ylabel='Chemistry'>

# %%
sns.jointplot(data=pdcluster,x='Maths',y='Chemistry')
