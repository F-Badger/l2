// %% [markdown]
// # Systems Programming
//
// <img src="images/durhamlogo.png" alt="Durham University" style="float: right; margin-right: 15px;" width="300">
//
//
// ### Lecture 7: Pointers
//
// Stuart James
//
// stuart.a.james@durham.ac.uk

// %% [markdown]
// # Recap
//
// https://PollEv.com/stuartjames
//
// <center><img src="images\quiz-qr.png" alt="Poll Link" width="400"></center>

// %% [markdown]
// # Recap Union & Struct

// %%
#include <stdio.h>
#define TITLE_LEN 8
#define AUTHOR_LEN 8
#define DESIGN_LEN 8

struct s_catalog_item {
  int stock_number;
  double price;
  int item_type;
  char title[TITLE_LEN+1];
  char author[AUTHOR_LEN+1];
  int num_pages;
  char design[DESIGN_LEN+1];
  int colors;
  int sizes;
};

struct u_catalog_item {
  int stock_number;
  double price;
  int item_type;
  union {
    struct {
      char title[TITLE_LEN+1];
      char author[AUTHOR_LEN+1];
      int num_pages;
    } book;
    struct {
      char design[DESIGN_LEN+1];
    } mug;
    struct {
      char design[DESIGN_LEN+1];
      int colors;
      int sizes;
    } shirt;
  } item;
};

int main(){
    // Accessing the original struct:
    struct s_catalog_item  c_struct; 
    c_struct.title[0] = 't';
    
    // Accessing our new data structure:
    struct u_catalog_item  c_union; 
    c_union.item.book.title[0] = 't';
    
    return 0;
}

// %% [markdown]
// # Recap: `typedef`

// %%
typedef struct coords {
  int x;
  int y;
} point;


typedef union id_thing {
  int i;
  double d;
} number;

int main(){
    point p1 = {5, 4}; // instead of struct point p1;
    number n = {.d = 10.0}; // instead of union number n;
}

// %% [markdown]
// # Recap: IO

// %%
#include <stdio.h>

int main()
{
   printf ("Characters: %c %c \n", 'a', 65);
   printf ("Decimals: %d %ld\n", 1977, 650000L);
   printf ("Preceding with blanks: %10d \n", 1977);
   printf ("Preceding with zeros: %010d \n", 1977);
   printf ("Some different radices: %d %x %o %#x %#o \n", 100, 100, 100, 100, 100);
   printf ("floats: %4.2f %+.0e %E \n", 3.1416, 3.1416, 3.1416);
   printf ("Width trick: %*d \n", 5, 10);
   printf ("%s \n", "A string");
   return 0;
}
// Out:
// Characters: a A
// Decimals: 1977 650000
// Preceding with blanks:       1977
// Preceding with zeros: 0000001977
// Some different radices: 100 64 144 0x64 0144
// floats: 3.14 +3e+00 3.141600E+00
// Width trick:    10
// A string

// %% [markdown]
// ## Starting this week
//
// # Pointers

// %% [markdown]
// # What is a Variable?
//
// - A logical name for an allocated area of memory, assigned to store a value of a certain type.
//
// ```c
// int i = 10;
// ```
//
// <center><img src="images/addressi.png" alt="variable" width="700"/></center>

// %% [markdown]
// # Pointer Variable
//
// <center><img src="images/addressrow.png" alt="variable" width="500"/></center>
//
// ```c
// int i = 10;
// ```
//
// - value of `i` is 10.
// - The memory address of `i` is `&i` and has a value of 4.

// %% [markdown]
// # Pointer Variable
//
// <center><img src="images/addressrow.png" alt="variable" width="500"/></center>
//
// - `int i = 10;`
//
//     - A pointer variable stores a memory address:
//         ```c
//         int *p;
//         p = &i;
//         ```
//     - now the pointer variable `p` stores the memory address of the variable `i`

// %% [markdown]
// # Pointers
//
// <center><img src="images/pointsto.png" alt="indirection" width="350"/></center>
//
// ```c
// int i = 10;   // simple variable
// int *p = &i;  // pointer variable
// ```
// - You can read the address operator `&` as "**_address of_**"

// %% [markdown]
// ```c
// printf("%d %d\n", i, *p ) ;
// ```
//
// * output: "`10 10`"
//
//     - You can read the indirection operator `*` as "**_value at_**"

// %% [markdown]
// # Basic Pointer Operations
//
// ```c
// int i = 5; // declare an int variable
//
// int *p;    // declare a variable pointer to an int
//
// p = &i;    // & "address of"
// ```
// - Use indirection operator `*` to access and modify the value:
//
// ```c
// *p = 7; // assign value of 7 to i
//
// *p = *p + 1; // add 1 to value of i
// ```

// %% [markdown]
// # The Indirection Operator: what not to do
//
// Applying the indirection operator to an uninitialised pointer variable causes undefined behaviour:
//
// ```c
// int *p;
//
// printf("%d", *p);   /*** WRONG ***/
// ```
//
// Assigning a value to `*p` is particularly dangerous:
//
// ```c
// int *p;
//
// *p = 1;            /*** DANGER ***/
// ```

// %% [markdown]
// # Pointer Assignment
//
// C allows the use of the assignment operator to copy pointers of the same type:
//
// - Assume that the following declaration is in effect:
//
// ```c
// int i, j, *p, *q;
// ```
//
// - Example of pointer assignment:
//
// ```c
// p = &i;
// ```

// %% [markdown]
// * There are other ways to assign pointers

// %% [markdown]
// # Pointer Assignment
//
//
// ```c
// int i, j, *p, *q;
// p = &i;
//
// ```
//
// - Another example of pointer assignment:
// c
// ```
// q = p;
// ```
//
// - `q` now points to the same place as `p`:
//
// <center><img src="images/twopointers.png" alt="copying pointers" width="400"/></center>

// %% [markdown]
// # Pointer Assignment
//
// `p` and `q` both point to `i`, so we can change `i` by assigning a value to `*p` **or** `*q`:
//
// ```c
// *p = 1;
// ```
// <center><img src="images/twopointers1.png" alt="copying pointers" width="400"/></center>
//
// - Any number of pointer variables may point to the same object

// %% [markdown]
// # Pointer Assignment
//
// `p` and `q` both point to `i`, so we can change `i` by assigning a value to `*p` **or** `*q`:
//
// ```c
// *q = 2;
// ```
// <center><img src="images/twopointers2.png" alt="copying pointers" width="400"/></center>
//
// - Any number of pointer variables may point to the same object

// %% [markdown]
// # Pointers as Arguments
//
// - We can try writing a `swap()` function that could modify its arguments, but it won’t really work.
//
// - By passing a pointer to a variable instead of the value of the variable, `swap()` can be fixed.

// %% [markdown]
// # Swap
//
// We want to write a simple function in C to swap the values of two integer variables, `x` and `y`:
//
// ```c
// void swap(int a, int b) {
//     int temp;
//     temp = a;
//     a = b;
//     b = temp;
// }
// ```
//
// - will this work when we call `swap(x,y)`?

// %% [markdown]
// - spoiler alert: **NO!**

// %%
#include <stdio.h>
void swap(int a, int b);

int main(){
  int x = 8;
  int y = 44;
  swap(x,y);
  printf("x = %d  y = %d\n", x, y);
  return 0;
}
void swap(int a, int b) {
  int temp = a;
  a = b;
  b = temp;
}
// Out:
// x = 8  y = 44

// %% [markdown]
// # Swap
//
// By default, C uses "call by value". Now let's use pointers:
//
// ```c
// void swap(int *a, int *b) {
//   int temp;
//   temp = *a;
//   *a = *b;
//   *b = temp;
// }
// ```
//
// - will this work when we call `swap(&x,&y)`?

// %%
#include <stdio.h>
void swap(int *a, int *b);

int main(){
  int x = 8;
  int y = 44;
  printf("before swap: x = %d  y = %d\n", x, y);
  swap(&x,&y);
  printf(" after swap: x = %d  y = %d\n", x, y);
  return 0;
}
void swap(int *a, int *b) {
  int temp = *a;
  *a = *b;
  *b = temp;
}
// Out:
// input_line_33:3:11: error: function definition is not allowed here
// int main(){
//           ^
// input_line_33:11:27: error: function definition is not allowed here
// void swap(int *a, int *b) {
//                           ^
// Interpreter Error:

// %% [markdown]
// # Pointers as Arguments
//
// Arguments in calls of `scanf()` are pointers:
//
// ```c
// int i;
// ...
// scanf("%d", &i);
// ```
//
// - Without the `&`, `scanf()` would be supplied with the value of `i`

// %% [markdown]
// # Pointers as Arguments
//
// - Although `scanf()`’s arguments must be pointers, it’s not always true that every argument needs the `&` operator:
//
// ```c
// int i, *p;
// ...
// p = &i;
// scanf("%d", p);
// ```
//
// - Using the `&` operator in the call would be **wrong**:
//
// ```c
// scanf("%d", &p); /*** WRONG ***/
// ```

// %% [markdown]
// # Arrays in C
//
// ```c
// int a[10];
// ```
//
// - declares a fixed size array holding ten `int` values.
//
// <center><img src="images/arry.png" alt="arry" width="900"/></center>
//
// - `a[i]` is the `i`th element of the array
// - `sizeof(a)` = 10 * `sizeof(int)` = 40 bytes
// - The array is stored in memory as a single contiguous block of 40 bytes (10 ints) in size!

// %% [markdown]
// # Arrays in C
//
// ```c
// int a[10];
// ```
//
// <center><img src="images/arry.png" alt="arry" width="900"/></center>
//
// Note that `sizeof(a) / sizeof(a[0])` = 10
// - a common way of checking the number of elements in an array.

// %% [markdown]
// We can’t pass an array to a function, but we can pass a pointer to it.
//
// - We will also need to pass the length of the array.

// %% [markdown]
// # Strings
//
// In C, strings are represented as an array of characters.
//
// ```c
// char a[] = "Hello worlds";
// char b[13];
// b = a; // Not allowed
// char *c;
// c = a; // Allowed
// ```
// - This will set pointer `c` to the same address as `a`
//
// - Assignment of an array to array is not supported in C
//
// - Instead, we can use `strcpy(b,a);`
//     - first argument is the destination - need to `#include <string.h>`

// %% [markdown]
// # Strings
//
// ```c
// char a[] = "Hello";
// ```
// `strlen(a)` = 5
//
// `sizeof(a)` = 6

// %% [markdown]
// - Strings are null terminated – important when allocating space to store them!
//
// ```c
// printf("%s %c\n", a, a[0]);
// ```
//
// - Output is: **Hello H**
//     - Variable `a` represents the memory address of the start of the string.

// %% [markdown]
// #  Pointers, Strings and Arrays
//
// <center><img src="images/array2.png" alt="arry" width="900"/></center>
//
// ```c
// char a[] = "Hello";
// char *a = "Hello";
// ```
//
// - These are equivalent declarations, and create the identical bytes in memory, as shown above.
//
// - Pointers and arrays are often used interchangeably!

// %% [markdown]
// - However, some behaviour might be different:

// %%
#include <stdio.h>
#include <string.h>

int main() {    
    char a[] = "Hello";
    char *b = "Hello";
    printf("size of string is %lu - size of pointer is %lu", sizeof(a), sizeof(b));
}
// Out:
// size of string is 6 - size of pointer is 8

// %% [markdown]
// - using `sizeof(a)` will give 6 in the first case (the size of the array) and 8 in the second case (the size of the pointer).
//
// - In the second case, the string "Hello" is constant and cannot be modified.

// %% [markdown]
// # Pointer Arithmetic
//
// ```c
// int a[10];
// int *pa;
// ```
// This pair of statements are equivalent using array or pointer notation:
// ```c
// pa = &a[0];
// pa = a;
// ```
// <center><img src="images/point2first.png" alt="point to array" width="600"/></center>

// %% [markdown]
// # Pointer Arithmetic
//
// ```c
// int a[10];
// int *pa;
// ```
// This pair of statements are also equivalent (+1 translates to +4 bytes (1 int)):
// ```c
// pa = &a[1];
// pa = (a+1);
// ```
// <center><img src="images/point2second.png" alt="point to array" width="600"/></center>

// %% [markdown]
// # Strange but True
//
// In C, if I write `a[x]`, this works by adding `x` to `a` to find the pointer
//
// - Hence `a[x]` is the same as `*(a+x)`
//     - This seems fine with `a[2]`
//     - But what if we write `2[a]`?
//         - It will compile and run - let's have a look!

// %%
#include <stdio.h>

int main() {
    char a[] = "Hello Worlds";
    char *b;
    printf("The fifth character of %s is %c\n", a, a[4]);
    printf("The fifth character of %s is %c\n", a, *(a+4));
    printf("The fifth character of %s is %c\n", a, 4[a]);
    b=a;
    b=b+4;
    printf("The fifth character of %s is %c\n", a, *b);

    return 0;
}
// Out:
// The fifth character of Hello Worlds is o
// The fifth character of Hello Worlds is o
// The fifth character of Hello Worlds is o
// The fifth character of Hello Worlds is o

// %% [markdown]
// # Strange but True
//
// How about `a[-4]`?
//
// - Interpreted as `*(a + -4)`
//
// **is the next snippet valid?**

// %%
#include <stdio.h>

int main() {
    
    int *p;
    int j = 20; // Stack order, Before? 
    int i = 5;
    p = &i;
//     int j = 20; // Stack order, After?
    
    printf("%d %d\n", p[0], p[1]);
    return 0;
}
// Out:
// 5 20

// %% [markdown]
// # Peeking at Memory
//
// - We can look at bits of memory.
//
// - We can find adjacent local variables and parameters.
//
// - Easy to make mistakes!
//
// - We cannot always tell what the data is by looking at it.

// %%
#include <stdio.h>

int main(){
  int x,y;   
  x = 5;
  y = 9;
  

  int *z = &x;

  z--;
  printf("Before x : %d\n", *z);
  z+=2;
  printf("After  x : %d\n\n", *z);

  z = &x - 5;
  while(z - &x <10){
    printf("At %p : %d\n", z, *z);
    printf("At %p : %p\n\n", &z, z);
    z++;
  }
  return 0;
}
// Out:
// Before x : 9
// After  x : 0
//
// At 0x30d1c1c94 : 3
// At 0x30d1c1c98 : 0x30d1c1c94
//
// At 0x30d1c1c98 : 219946136
// At 0x30d1c1c98 : 0x30d1c1c98
//
// At 0x30d1c1c9c : 3
// At 0x30d1c1c98 : 0x30d1c1c9c
//
// At 0x30d1c1ca0 : 78110672
// At 0x30d1c1c98 : 0x30d1c1ca0
//
// At 0x30d1c1ca4 : 9
// At 0x30d1c1c98 : 0x30d1c1ca4
//
// At 0x30d1c1ca8 : 5
// At 0x30d1c1c98 : 0x30d1c1ca8
//
// At 0x30d1c1cac : 0
// At 0x30d1c1c98 : 0x30d1c1cac
//
// At 0x30d1c1cb0 : 219946240
// At 0x30d1c1c98 : 0x30d1c1cb0
//
// At 0x30d1c1cb4 : 3
// At 0x30d1c1c98 : 0x30d1c1cb4
//
// At 0x30d1c1cb8 : 74241458
// At 0x30d1c1c98 : 0x30d1c1cb8
//
// At 0x30d1c1cbc : 1
// At 0x30d1c1c98 : 0x30d1c1cbc
//
// At 0x30d1c1cc0 : 219946104
// At 0x30d1c1c98 : 0x30d1c1cc0
//
// At 0x30d1c1cc4 : 3
// At 0x30d1c1c98 : 0x30d1c1cc4
//
// At 0x30d1c1cc8 : 78249368
// At 0x30d1c1c98 : 0x30d1c1cc8
//
// At 0x30d1c1ccc : 2
// At 0x30d1c1c98 : 0x30d1c1ccc

// %% [markdown]
// # Pointers to Pointers
//
// We can also have pointers to pointers.
//
// ```c
// int i, *p, **q;
// p = &i;
// q = &p;
// ```
//
// <center><img src="images/pointer2pointer.png" alt="pointer to pointer" width="900"/></center>
//
// - Now `i`, `*p` and `**q` all have value 10.

// %% [markdown]
// # Breaking Things
//
// Using pointers, we can write any value in any place!
//
// - This can upset the system.
//
// - Segmentation fault occurs: hardware tells OS a memory access is not allowed.

// %%
#include <stdlib.h>
#include <stdio.h>

int main(){

  int x = 1;
  int *p = &x;
  int i = 1;

  while(-1){

    p++;
    
    // write a value
    *p = rand();
    // *p = 1234;
    
    printf("%d : so far so good. Content of %p is %d\n", i, p, *p);
    i++;
  }
  
  return 0;
}
// Out:
// 1 : so far so good. Content of 0x3049d1cac is 16807
// 2 : so far so good. Content of 0x3049d1cb0 is 282475249
// 3 : so far so good. Content of 0x3049d1cb4 is 1622650073
// 4 : so far so good. Content of 0x3049d1cb8 is 984943658
// 5 : so far so good. Content of 0x3049d1cbc is 1144108930
// 6 : so far so good. Content of 0x3049d1cc0 is 470211272
// 7 : so far so good. Content of 0x3049d1cc4 is 101027544
// 8 : so far so good. Content of 0x3049d1cc8 is 1457850878
// 9 : so far so good. Content of 0x3049d1ccc is 1458777923
// 10 : so far so good. Content of 0x3049d1cd0 is 2007237709
// 11 : so far so good. Content of 0x3049d1cd4 is 823564440
// 12 : so far so good. Content of 0x3049d1cd8 is 1115438165
// 13 : so far so good. Content of 0x3049d1cdc is 1784484492
// 14 : so far so good. Content of 0x3049d1ce0 is 74243042
// 15 : so far so good. Content of 0x3049d1ce4 is 114807987
// 16 : so far so good. Content of 0x3049d1ce8 is 1137522503
// 17 : so far so good. Content of 0x3049d1cec is 1441282327
// 18 : so far so good. Content of 0x3049d1cf0 is 16531729
// 19 : so far so good. Content of 0x3049d1cf4 is 823378840
// 20 : so far so good. Content of 0x3049d1cf8 is 143542612
// 21 : so far so good. Content of 0x3049d1cfc is 896544303
// 22 : so far so good. Content of 0x3049d1d00 is 1474833169
// 23 : so far so good. Content of 0x3049d1d04 is 1264817709
// 24 : so far so good. Content of 0x3049d1d08 is 1998097157
// 25 : so far so good. Content of 0x3049d1d0c is 1817129560
// 26 : so far so good. Content of 0x3049d1d10 is 1131570933
// 27 : so far so good. Content of 0x3049d1d14 is 197493099
// 28 : so far so good. Content of 0x3049d1d18 is 1404280278
// 29 : so far so good. Content of 0x3049d1d1c is 893351816
// 30 : so far so good. Content of 0x3049d1d20 is 1505795335
// 31 : so far so good. Content of 0x3049d1d24 is 1954899097
// 32 : so far so good. Content of 0x3049d1d28 is 1636807826
// 33 : so far so good. Content of 0x3049d1d2c is 563613512
// 34 : so far so good. Content of 0x3049d1d30 is 101929267
// 35 : so far so good. Content of 0x3049d1d34 is 1580723810
// 36 : so far so good. Content of 0x3049d1d38 is 704877633
// 37 : so far so good. Content of 0x3049d1d3c is 1358580979
// 38 : so far so good. Content of 0x3049d1d40 is 1624379149
// 39 : so far so good. Content of 0x3049d1d44 is 2128236579
// 40 : so far so good. Content of 0x3049d1d48 is 784558821
// 41 : so far so good. Content of 0x3049d1d4c is 530511967
// 42 : so far so good. Content of 0x3049d1d50 is 2110010672
// 43 : so far so good. Content of 0x3049d1d54 is 1551901393
// 44 : so far so good. Content of 0x3049d1d58 is 1617819336
// 45 : so far so good. Content of 0x3049d1d5c is 1399125485
// 46 : so far so good. Content of 0x3049d1d60 is 156091745
// 47 : so far so good. Content of 0x3049d1d64 is 1356425228
// 48 : so far so good. Content of 0x3049d1d68 is 1899894091
// 49 : so far so good. Content of 0x3049d1d6c is 585640194
// 50 : so far so good. Content of 0x3049d1d70 is 937186357
// 51 : so far so good. Content of 0x3049d1d74 is 1646035001
// 52 : so far so good. Content of 0x3049d1d78 is 1025921153
// 53 : so far so good. Content of 0x3049d1d7c is 510616708
// 54 : so far so good. Content of 0x3049d1d80 is 590357944
// 55 : so far so good. Content of 0x3049d1d84 is 771515668
// 56 : so far so good. Content of 0x3049d1d88 is 357571490
// 57 : so far so good. Content of 0x3049d1d8c is 1044788124
// 58 : so far so good. Content of 0x3049d1d90 is 1927702196
// 59 : so far so good. Content of 0x3049d1d94 is 1952509530
// 60 : so far so good. Content of 0x3049d1d98 is 130060903
// 61 : so far so good. Content of 0x3049d1d9c is 1942727722
// 62 : so far so good. Content of 0x3049d1da0 is 1083454666
// 63 : so far so good. Content of 0x3049d1da4 is 1108728549
// 64 : so far so good. Content of 0x3049d1da8 is 685118024
// 65 : so far so good. Content of 0x3049d1dac is 2118797801
// 66 : so far so good. Content of 0x3049d1db0 is 1060806853
// 67 : so far so good. Content of 0x3049d1db4 is 571540977
// 68 : so far so good. Content of 0x3049d1db8 is 194847408
// 69 : so far so good. Content of 0x3049d1dbc is 2035308228
// 70 : so far so good. Content of 0x3049d1dc0 is 158374933
// 71 : so far so good. Content of 0x3049d1dc4 is 1075260298
// 72 : so far so good. Content of 0x3049d1dc8 is 824938981
// 73 : so far so good. Content of 0x3049d1dcc is 595028635
// 74 : so far so good. Content of 0x3049d1dd0 is 1962408013
// 75 : so far so good. Content of 0x3049d1dd4 is 1137623865
// 76 : so far so good. Content of 0x3049d1dd8 is 997389814
// 77 : so far so good. Content of 0x3049d1ddc is 2020739063
// 78 : so far so good. Content of 0x3049d1de0 is 107554536
// 79 : so far so good. Content of 0x3049d1de4 is 1635339425
// 80 : so far so good. Content of 0x3049d1de8 is 1654001669
// 81 : so far so good. Content of 0x3049d1dec is 1777724115
// 82 : so far so good. Content of 0x3049d1df0 is 269220094
// 83 : so far so good. Content of 0x3049d1df4 is 34075629
// 84 : so far so good. Content of 0x3049d1df8 is 1478446501
// 85 : so far so good. Content of 0x3049d1dfc is 1864546517
// 86 : so far so good. Content of 0x3049d1e00 is 1351934195
// 87 : so far so good. Content of 0x3049d1e04 is 1581030105
// 88 : so far so good. Content of 0x3049d1e08 is 1557810404
// 89 : so far so good. Content of 0x3049d1e0c is 2146319451
// 90 : so far so good. Content of 0x3049d1e10 is 1908194298
// 91 : so far so good. Content of 0x3049d1e14 is 500782188
// 92 : so far so good. Content of 0x3049d1e18 is 657821123
// 93 : so far so good. Content of 0x3049d1e1c is 753799505
// 94 : so far so good. Content of 0x3049d1e20 is 1102246882
// 95 : so far so good. Content of 0x3049d1e24 is 1269406752
// 96 : so far so good. Content of 0x3049d1e28 is 1816731566
// 97 : so far so good. Content of 0x3049d1e2c is 884936716
// 98 : so far so good. Content of 0x3049d1e30 is 1807130337
// 99 : so far so good. Content of 0x3049d1e34 is 578354438
// 100 : so far so good. Content of 0x3049d1e38 is 892053144
// 101 : so far so good. Content of 0x3049d1e3c is 1153851501
// 102 : so far so good. Content of 0x3049d1e40 is 1004844897
// 103 : so far so good. Content of 0x3049d1e44 is 616783871
// 104 : so far so good. Content of 0x3049d1e48 is 382955828
// 105 : so far so good. Content of 0x3049d1e4c is 330111137
// 106 : so far so good. Content of 0x3049d1e50 is 1227619358
// 107 : so far so good. Content of 0x3049d1e54 is 1723153177
// 108 : so far so good. Content of 0x3049d1e58 is 70982397
// 109 : so far so good. Content of 0x3049d1e5c is 1147722294
// 110 : so far so good. Content of 0x3049d1e60 is 1070477904
// 111 : so far so good. Content of 0x3049d1e64 is 2051621609
// 112 : so far so good. Content of 0x3049d1e68 is 1606946231
// 113 : so far so good. Content of 0x3049d1e6c is 1190959745
// 114 : so far so good. Content of 0x3049d1e70 is 1912844175
// 115 : so far so good. Content of 0x3049d1e74 is 1341853635
// 116 : so far so good. Content of 0x3049d1e78 is 1808266298
// 117 : so far so good. Content of 0x3049d1e7c is 343098142
// 118 : so far so good. Content of 0x3049d1e80 is 456880399
// 119 : so far so good. Content of 0x3049d1e84 is 1534827968
// 120 : so far so good. Content of 0x3049d1e88 is 280090412
// 121 : so far so good. Content of 0x3049d1e8c is 195400260
// 122 : so far so good. Content of 0x3049d1e90 is 589673557
// 123 : so far so good. Content of 0x3049d1e94 is 6441594
// 124 : so far so good. Content of 0x3049d1e98 is 889688008
// 125 : so far so good. Content of 0x3049d1e9c is 57716395
// 126 : so far so good. Content of 0x3049d1ea0 is 1524325968
// 127 : so far so good. Content of 0x3049d1ea4 is 2014119113
// 128 : so far so good. Content of 0x3049d1ea8 is 515204530
// 129 : so far so good. Content of 0x3049d1eac is 388471006
// 130 : so far so good. Content of 0x3049d1eb0 is 681910962
// 131 : so far so good. Content of 0x3049d1eb4 is 1904797942
// 132 : so far so good. Content of 0x3049d1eb8 is 1400285365
// 133 : so far so good. Content of 0x3049d1ebc is 322842082
// 134 : so far so good. Content of 0x3049d1ec0 is 1463179852
// 135 : so far so good. Content of 0x3049d1ec4 is 828530767
// 136 : so far so good. Content of 0x3049d1ec8 is 832633821
// 137 : so far so good. Content of 0x3049d1ecc is 1073185695
// 138 : so far so good. Content of 0x3049d1ed0 is 316824712
// 139 : so far so good. Content of 0x3049d1ed4 is 1260973671
// 140 : so far so good. Content of 0x3049d1ed8 is 1815859901
// 141 : so far so good. Content of 0x3049d1edc is 1267248590
// 142 : so far so good. Content of 0x3049d1ee0 is 2051724831
// 143 : so far so good. Content of 0x3049d1ee4 is 1194314738
// 144 : so far so good. Content of 0x3049d1ee8 is 318153057
// 145 : so far so good. Content of 0x3049d1eec is 2111631616
// 146 : so far so good. Content of 0x3049d1ef0 is 877819790
// 147 : so far so good. Content of 0x3049d1ef4 is 304555640
// 148 : so far so good. Content of 0x3049d1ef8 is 1213110679
// 149 : so far so good. Content of 0x3049d1efc is 541437335
// 150 : so far so good. Content of 0x3049d1f00 is 1049077006
// 151 : so far so good. Content of 0x3049d1f04 is 996497972
// 152 : so far so good. Content of 0x3049d1f08 is 2063936098
// 153 : so far so good. Content of 0x3049d1f0c is 270649095
// 154 : so far so good. Content of 0x3049d1f10 is 428975319
// 155 : so far so good. Content of 0x3049d1f14 is 685583454
// 156 : so far so good. Content of 0x3049d1f18 is 1351345223
// 157 : so far so good. Content of 0x3049d1f1c is 272112289
// 158 : so far so good. Content of 0x3049d1f20 is 1398556760
// 159 : so far so good. Content of 0x3049d1f24 is 1334948905
// 160 : so far so good. Content of 0x3049d1f28 is 1724586126
// 161 : so far so good. Content of 0x3049d1f2c is 532236123
// 162 : so far so good. Content of 0x3049d1f30 is 1023129506
// 163 : so far so good. Content of 0x3049d1f34 is 836045813
// 164 : so far so good. Content of 0x3049d1f38 is 436476770
// 165 : so far so good. Content of 0x3049d1f3c is 60935238
// 166 : so far so good. Content of 0x3049d1f40 is 1936329094
// 167 : so far so good. Content of 0x3049d1f44 is 915896220
// 168 : so far so good. Content of 0x3049d1f48 is 304987844
// 169 : so far so good. Content of 0x3049d1f4c is 2034712366
// 170 : so far so good. Content of 0x3049d1f50 is 881140534
// 171 : so far so good. Content of 0x3049d1f54 is 281725226
// 172 : so far so good. Content of 0x3049d1f58 is 1901915394
// 173 : so far so good. Content of 0x3049d1f5c is 197941363
// 174 : so far so good. Content of 0x3049d1f60 is 348318738
// 175 : so far so good. Content of 0x3049d1f64 is 152607844
// 176 : so far so good. Content of 0x3049d1f68 is 784559590
// 177 : so far so good. Content of 0x3049d1f6c is 543436550
// 178 : so far so good. Content of 0x3049d1f70 is 290145159
// 179 : so far so good. Content of 0x3049d1f74 is 1681808623
// 180 : so far so good. Content of 0x3049d1f78 is 977764947
// 181 : so far so good. Content of 0x3049d1f7c is 750597385
// 182 : so far so good. Content of 0x3049d1f80 is 971307217
// 183 : so far so good. Content of 0x3049d1f84 is 1737195272
// 184 : so far so good. Content of 0x3049d1f88 is 2000755539
// 185 : so far so good. Content of 0x3049d1f8c is 1399399247
// 186 : so far so good. Content of 0x3049d1f90 is 462242385
// 187 : so far so good. Content of 0x3049d1f94 is 1459413496
// 188 : so far so good. Content of 0x3049d1f98 is 1951894885
// 189 : so far so good. Content of 0x3049d1f9c is 537140623
// 190 : so far so good. Content of 0x3049d1fa0 is 1848682420
// 191 : so far so good. Content of 0x3049d1fa4 is 1012028144
// 192 : so far so good. Content of 0x3049d1fa8 is 1086531968
// 193 : so far so good. Content of 0x3049d1fac is 1289335735
// 194 : so far so good. Content of 0x3049d1fb0 is 1755699915
// 195 : so far so good. Content of 0x3049d1fb4 is 1623161625
// 196 : so far so good. Content of 0x3049d1fb8 is 992663534
// 197 : so far so good. Content of 0x3049d1fbc is 2043046042
// 198 : so far so good. Content of 0x3049d1fc0 is 1358796011
// 199 : so far so good. Content of 0x3049d1fc4 is 943454679
// 200 : so far so good. Content of 0x3049d1fc8 is 1771024152
// 201 : so far so good. Content of 0x3049d1fcc is 1479575244
// 202 : so far so good. Content of 0x3049d1fd0 is 1507977295
// 203 : so far so good. Content of 0x3049d1fd4 is 2119878818
// 204 : so far so good. Content of 0x3049d1fd8 is 2049590396
// 205 : so far so good. Content of 0x3049d1fdc is 1828087692
// 206 : so far so good. Content of 0x3049d1fe0 is 621301815
// 207 : so far so good. Content of 0x3049d1fe4 is 1154112991
// 208 : so far so good. Content of 0x3049d1fe8 is 1104740033
// 209 : so far so good. Content of 0x3049d1fec is 222122669
// 210 : so far so good. Content of 0x3049d1ff0 is 889119397
// 211 : so far so good. Content of 0x3049d1ff4 is 1238489553
// 212 : so far so good. Content of 0x3049d1ff8 is 1882410547
// 213 : so far so good. Content of 0x3049d1ffc is 944975825
// 214 : so far so good. Content of 0x3049d2000 is 1567121210
// 215 : so far so good. Content of 0x3049d2004 is 1866729662
// 216 : so far so good. Content of 0x3049d2008 is 1536830211
// 217 : so far so good. Content of 0x3049d200c is 1719533808
// 218 : so far so good. Content of 0x3049d2010 is 1517273377
// 219 : so far so good. Content of 0x3049d2014 is 1592822761
// 220 : so far so good. Content of 0x3049d2018 is 41000625
// 221 : so far so good. Content of 0x3049d201c is 1902737335
// 222 : so far so good. Content of 0x3049d2020 is 1127401868
// 223 : so far so good. Content of 0x3049d2024 is 994977995
// 224 : so far so good. Content of 0x3049d2028 is 140002776
// 225 : so far so good. Content of 0x3049d202c is 1532062767
// 226 : so far so good. Content of 0x3049d2030 is 1049997439
// 227 : so far so good. Content of 0x3049d2034 is 1433829874
// 228 : so far so good. Content of 0x3049d2038 is 1464689331
// 229 : so far so good. Content of 0x3049d203c is 428540556
// 230 : so far so good. Content of 0x3049d2040 is 1968456301
// 231 : so far so good. Content of 0x3049d2044 is 1859468872
// 232 : so far so good. Content of 0x3049d2048 is 1911300560
// 233 : so far so good. Content of 0x3049d204c is 1168120094
// 234 : so far so good. Content of 0x3049d2050 is 298918984
// 235 : so far so good. Content of 0x3049d2054 is 967113755
// 236 : so far so good. Content of 0x3049d2058 is 2124639789
// 237 : so far so good. Content of 0x3049d205c is 462851407
// 238 : so far so good. Content of 0x3049d2060 is 957828015
// 239 : so far so good. Content of 0x3049d2064 is 678030193
// 240 : so far so good. Content of 0x3049d2068 is 1105222769
// 241 : so far so good. Content of 0x3049d206c is 1893015680
// 242 : so far so good. Content of 0x3049d2070 is 944303455
// 243 : so far so good. Content of 0x3049d2074 is 1004016855
// 244 : so far so good. Content of 0x3049d2078 is 1732267506
// 245 : so far so good. Content of 0x3049d207c is 784170963
// 246 : so far so good. Content of 0x3049d2080 is 454233502
// 247 : so far so good. Content of 0x3049d2084 is 2145586676
// 248 : so far so good. Content of 0x3049d2088 is 329863108
// 249 : so far so good. Content of 0x3049d208c is 1353963249
// 250 : so far so good. Content of 0x3049d2090 is 1323602331
// 251 : so far so good. Content of 0x3049d2094 is 1277844
// 252 : so far so good. Content of 0x3049d2098 is 1887638
// 253 : so far so good. Content of 0x3049d209c is 1660760808
// 254 : so far so good. Content of 0x3049d20a0 is 1561939997
// 255 : so far so good. Content of 0x3049d20a4 is 685428651
// 256 : so far so good. Content of 0x3049d20a8 is 897054849
// 257 : so far so good. Content of 0x3049d20ac is 1465645203
// 258 : so far so good. Content of 0x3049d20b0 is 1461495731
// 259 : so far so good. Content of 0x3049d20b4 is 440796531
// 260 : so far so good. Content of 0x3049d20b8 is 1796198014
// 261 : so far so good. Content of 0x3049d20bc is 1522395419
// 262 : so far so good. Content of 0x3049d20c0 is 1779636775
// 263 : so far so good. Content of 0x3049d20c4 is 203042009
// 264 : so far so good. Content of 0x3049d20c8 is 175530180
// 265 : so far so good. Content of 0x3049d20cc is 1640687929
// 266 : so far so good. Content of 0x3049d20d0 is 1351995223
// 267 : so far so good. Content of 0x3049d20d4 is 459244054
// 268 : so far so good. Content of 0x3049d20d8 is 458588260
// 269 : so far so good. Content of 0x3049d20dc is 174076737
// 270 : so far so good. Content of 0x3049d20e0 is 834991545
// 271 : so far so good. Content of 0x3049d20e4 is 2044747317
// 272 : so far so good. Content of 0x3049d20e8 is 2034837525
// 273 : so far so good. Content of 0x3049d20ec is 837204200
// 274 : so far so good. Content of 0x3049d20f0 is 578134256
// 275 : so far so good. Content of 0x3049d20f4 is 1486421564
// 276 : so far so good. Content of 0x3049d20f8 is 609960597
// 277 : so far so good. Content of 0x3049d20fc is 1668306648
// 278 : so far so good. Content of 0x3049d2100 is 1683337704
// 279 : so far so good. Content of 0x3049d2104 is 907225550
// 280 : so far so good. Content of 0x3049d2108 is 605925150
// 281 : so far so good. Content of 0x3049d210c is 416541976
// 282 : so far so good. Content of 0x3049d2110 is 24301412
// 283 : so far so good. Content of 0x3049d2114 is 411938554
// 284 : so far so good. Content of 0x3049d2118 is 2111482797
// 285 : so far so good. Content of 0x3049d211c is 524102504
// 286 : so far so good. Content of 0x3049d2120 is 1760348381
// 287 : so far so good. Content of 0x3049d2124 is 293034748
// 288 : so far so good. Content of 0x3049d2128 is 855007065
// 289 : so far so good. Content of 0x3049d212c is 1290659378
// 290 : so far so good. Content of 0x3049d2130 is 379847699
// 291 : so far so good. Content of 0x3049d2134 is 1778878209
// 292 : so far so good. Content of 0x3049d2138 is 338725129
// 293 : so far so good. Content of 0x3049d213c is 2121578553
// 294 : so far so good. Content of 0x3049d2140 is 552265483
// 295 : so far so good. Content of 0x3049d2144 is 501650447
// 296 : so far so good. Content of 0x3049d2148 is 218264607
// 297 : so far so good. Content of 0x3049d214c is 471180773
// 298 : so far so good. Content of 0x3049d2150 is 1363045322
// 299 : so far so good. Content of 0x3049d2154 is 1494664305
// 300 : so far so good. Content of 0x3049d2158 is 1706755176
// 301 : so far so good. Content of 0x3049d215c is 1495170053
// 302 : so far so good. Content of 0x3049d2160 is 1616927224
// 303 : so far so good. Content of 0x3049d2164 is 1437784630
// 304 : so far so good. Content of 0x3049d2168 is 1360280366
// 305 : so far so good. Content of 0x3049d216c is 121205400
// 306 : so far so good. Content of 0x3049d2170 is 1284660444
// 307 : so far so good. Content of 0x3049d2174 is 487495370
// 308 : so far so good. Content of 0x3049d2178 is 684570285
// 309 : so far so good. Content of 0x3049d217c is 1502883016
// 310 : so far so good. Content of 0x3049d2180 is 252193898
// 311 : so far so good. Content of 0x3049d2184 is 1637608155
// 312 : so far so good. Content of 0x3049d2188 is 1129841133
// 313 : so far so good. Content of 0x3049d218c is 1189515557
// 314 : so far so good. Content of 0x3049d2190 is 1262696576
// 315 : so far so good. Content of 0x3049d2194 is 707953178
// 316 : so far so good. Content of 0x3049d2198 is 1509658266
// 317 : so far so good. Content of 0x3049d219c is 307187357
// 318 : so far so good. Content of 0x3049d21a0 is 347221711
// 319 : so far so good. Content of 0x3049d21a4 is 1042227878
// 320 : so far so good. Content of 0x3049d21a8 is 1847320614
// 321 : so far so good. Content of 0x3049d21ac is 1746474819
// 322 : so far so good. Content of 0x3049d21b0 is 1195795737
// 323 : so far so good. Content of 0x3049d21b4 is 1586983133
// 324 : so far so good. Content of 0x3049d21b8 is 678620591
// 325 : so far so good. Content of 0x3049d21bc is 290623720
// 326 : so far so good. Content of 0x3049d21c0 is 1135048762
// 327 : so far so good. Content of 0x3049d21c4 is 667306633
// 328 : so far so good. Content of 0x3049d21c8 is 1262976197
// 329 : so far so good. Content of 0x3049d21cc is 1112576031
// 330 : so far so good. Content of 0x3049d21d0 is 925238588
// 331 : so far so good. Content of 0x3049d21d4 is 555860589
// 332 : so far so good. Content of 0x3049d21d8 is 795054873
// 333 : so far so good. Content of 0x3049d21dc is 843998877
// 334 : so far so good. Content of 0x3049d21e0 is 959637304
// 335 : so far so good. Content of 0x3049d21e4 is 1021979358
// 336 : so far so good. Content of 0x3049d21e8 is 832861200
// 337 : so far so good. Content of 0x3049d21ec is 599777254
// 338 : so far so good. Content of 0x3049d21f0 is 168068960
// 339 : so far so good. Content of 0x3049d21f4 is 794014915
// 340 : so far so good. Content of 0x3049d21f8 is 545293947
// 341 : so far so good. Content of 0x3049d21fc is 1442645480
// 342 : so far so good. Content of 0x3049d2200 is 1452207730
// 343 : so far so good. Content of 0x3049d2204 is 1103669955
// 344 : so far so good. Content of 0x3049d2208 is 1564674546
// 345 : so far so good. Content of 0x3049d220c is 1547837107
// 346 : so far so good. Content of 0x3049d2210 is 2028841238
// 347 : so far so good. Content of 0x3049d2214 is 989340000
// 348 : so far so good. Content of 0x3049d2218 is 2018984926
// 349 : so far so good. Content of 0x3049d221c is 690545035
// 350 : so far so good. Content of 0x3049d2220 is 988774857
// 351 : so far so good. Content of 0x3049d2224 is 1110561113
// 352 : so far so good. Content of 0x3049d2228 is 1420250114
// 353 : so far so good. Content of 0x3049d222c is 862929593
// 354 : so far so good. Content of 0x3049d2230 is 1300601360
// 355 : so far so good. Content of 0x3049d2234 is 2118498354
// 356 : so far so good. Content of 0x3049d2238 is 322968418
// 357 : so far so good. Content of 0x3049d223c is 1439025357
// 358 : so far so good. Content of 0x3049d2240 is 738342585
// 359 : so far so good. Content of 0x3049d2244 is 1163313729
// 360 : so far so good. Content of 0x3049d2248 is 1122721015
// 361 : so far so good. Content of 0x3049d224c is 1780776563
// 362 : so far so good. Content of 0x3049d2250 is 32106102
// 363 : so far so good. Content of 0x3049d2254 is 588860917
// 364 : so far so good. Content of 0x3049d2258 is 1380786643
// 365 : so far so good. Content of 0x3049d225c is 1172819419
// 366 : so far so good. Content of 0x3049d2260 is 1971062967
// 367 : so far so good. Content of 0x3049d2264 is 572547747
// 368 : so far so good. Content of 0x3049d2268 is 2083245269
// 369 : so far so good. Content of 0x3049d226c is 529855395
// 370 : so far so good. Content of 0x3049d2270 is 1812423303
// 371 : so far so good. Content of 0x3049d2274 is 1490404473
// 372 : so far so good. Content of 0x3049d2278 is 978719103
// 373 : so far so good. Content of 0x3049d227c is 1754711748
// 374 : so far so good. Content of 0x3049d2280 is 47424385
// 375 : so far so good. Content of 0x3049d2284 is 345205658
// 376 : so far so good. Content of 0x3049d2288 is 1518163459
// 377 : so far so good. Content of 0x3049d228c is 1520045406
// 378 : so far so good. Content of 0x3049d2290 is 937673930
// 379 : so far so good. Content of 0x3049d2294 is 1250739824
// 380 : so far so good. Content of 0x3049d2298 is 1614285132
// 381 : so far so good. Content of 0x3049d229c is 2129300973
// 382 : so far so good. Content of 0x3049d22a0 is 1493959603
// 383 : so far so good. Content of 0x3049d22a4 is 600246897
// 384 : so far so good. Content of 0x3049d22a8 is 1618907920
// 385 : so far so good. Content of 0x3049d22ac is 367603950
// 386 : so far so good. Content of 0x3049d22b0 is 9135231
// 387 : so far so good. Content of 0x3049d22b4 is 1064488480
// 388 : so far so good. Content of 0x3049d22b8 is 171620203
// 389 : so far so good. Content of 0x3049d22bc is 350213900
// 390 : so far so good. Content of 0x3049d22c0 is 1939824520
// 391 : so far so good. Content of 0x3049d22c4 is 1681462533
// 392 : so far so good. Content of 0x3049d22c8 is 1603481258
// 393 : so far so good. Content of 0x3049d22cc is 937217003
// 394 : so far so good. Content of 0x3049d22d0 is 13618676
// 395 : so far so good. Content of 0x3049d22d4 is 1255820950
// 396 : so far so good. Content of 0x3049d22d8 is 1113423934
// 397 : so far so good. Content of 0x3049d22dc is 143558780
// 398 : so far so good. Content of 0x3049d22e0 is 1168279879
// 399 : so far so good. Content of 0x3049d22e4 is 836941832
// 400 : so far so good. Content of 0x3049d22e8 is 463482574
// 401 : so far so good. Content of 0x3049d22ec is 828433549
// 402 : so far so good. Content of 0x3049d22f0 is 1346174542
// 403 : so far so good. Content of 0x3049d22f4 is 1415306249
// 404 : so far so good. Content of 0x3049d22f8 is 1523252771
// 405 : so far so good. Content of 0x3049d22fc is 1156766310
// 406 : so far so good. Content of 0x3049d2300 is 601915879
// 407 : so far so good. Content of 0x3049d2304 is 1752200983
// 408 : so far so good. Content of 0x3049d2308 is 798669970
// 409 : so far so good. Content of 0x3049d230c is 1473392040
// 410 : so far so good. Content of 0x3049d2310 is 666082723
// 411 : so far so good. Content of 0x3049d2314 is 20073650
// 412 : so far so good. Content of 0x3049d2318 is 222902971
// 413 : so far so good. Content of 0x3049d231c is 1118753229
// 414 : so far so good. Content of 0x3049d2320 is 1666190318
// 415 : so far so good. Content of 0x3049d2324 is 473917746
// 416 : so far so good. Content of 0x3049d2328 is 118710299
// 417 : so far so good. Content of 0x3049d232c is 151687230
// 418 : so far so good. Content of 0x3049d2330 is 344185621
// 419 : so far so good. Content of 0x3049d2334 is 1554270776
// 420 : so far so good. Content of 0x3049d2338 is 637850124
// 421 : so far so good. Content of 0x3049d233c is 108668244
// 422 : so far so good. Content of 0x3049d2340 is 1026076958
// 423 : so far so good. Content of 0x3049d2344 is 981747696
// 424 : so far so good. Content of 0x3049d2348 is 1116666771
// 425 : so far so good. Content of 0x3049d234c is 958829064
// 426 : so far so good. Content of 0x3049d2350 is 322791560
// 427 : so far so good. Content of 0x3049d2354 is 614056598
// 428 : so far so good. Content of 0x3049d2358 is 1790318751
// 429 : so far so good. Content of 0x3049d235c is 1493869940
// 430 : so far so good. Content of 0x3049d2360 is 1240764503
// 431 : so far so good. Content of 0x3049d2364 is 1462789551
// 432 : so far so good. Content of 0x3049d2368 is 711192801
// 433 : so far so good. Content of 0x3049d236c is 123427205
// 434 : so far so good. Content of 0x3049d2370 is 2119315080
// 435 : so far so good. Content of 0x3049d2374 is 1164780418
// 436 : so far so good. Content of 0x3049d2378 is 3559274
// 437 : so far so good. Content of 0x3049d237c is 1838659649
// 438 : so far so good. Content of 0x3049d2380 is 63040413
// 439 : so far so good. Content of 0x3049d2384 is 810783320
// 440 : so far so good. Content of 0x3049d2388 is 1051519025
// 441 : so far so good. Content of 0x3049d238c is 1237322012
// 442 : so far so good. Content of 0x3049d2390 is 1586901783
// 443 : so far so good. Content of 0x3049d2394 is 1458854788
// 444 : so far so good. Content of 0x3049d2398 is 1151624117
// 445 : so far so good. Content of 0x3049d239c is 76424008
// 446 : so far so good. Content of 0x3049d23a0 is 263081550
// 447 : so far so good. Content of 0x3049d23a4 is 2090265324
// 448 : so far so good. Content of 0x3049d23a8 is 404319195
// 449 : so far so good. Content of 0x3049d23ac is 754451257
// 450 : so far so good. Content of 0x3049d23b0 is 1318824511
// 451 : so far so good. Content of 0x3049d23b4 is 1304835690
// 452 : so far so good. Content of 0x3049d23b8 is 270438666
// 453 : so far so good. Content of 0x3049d23bc is 1187262410
// 454 : so far so good. Content of 0x3049d23c0 is 2048760593
// 455 : so far so good. Content of 0x3049d23c4 is 766490553
// 456 : so far so good. Content of 0x3049d23c8 is 1799809565
// 457 : so far so good. Content of 0x3049d23cc is 2092190960
// 458 : so far so good. Content of 0x3049d23d0 is 556228742
// 459 : so far so good. Content of 0x3049d23d4 is 540151403
// 460 : so far so good. Content of 0x3049d23d8 is 911254352
// 461 : so far so good. Content of 0x3049d23dc is 1746007307
// 462 : so far so good. Content of 0x3049d23e0 is 1928256141
// 463 : so far so good. Content of 0x3049d23e4 is 525244910
// 464 : so far so good. Content of 0x3049d23e8 is 1633413200
// 465 : so far so good. Content of 0x3049d23ec is 1492192799
// 466 : so far so good. Content of 0x3049d23f0 is 970343127
// 467 : so far so good. Content of 0x3049d23f4 is 566120171
// 468 : so far so good. Content of 0x3049d23f8 is 1429157787
// 469 : so far so good. Content of 0x3049d23fc is 250334414
// 470 : so far so good. Content of 0x3049d2400 is 450031625
// 471 : so far so good. Content of 0x3049d2404 is 244116641
// 472 : so far so good. Content of 0x3049d2408 is 1174619517
// 473 : so far so good. Content of 0x3049d240c is 13055348
// 474 : so far so good. Content of 0x3049d2410 is 377901842
// 475 : so far so good. Content of 0x3049d2414 is 1287114315
// 476 : so far so good. Content of 0x3049d2418 is 927515974
// 477 : so far so good. Content of 0x3049d241c is 177181445
// 478 : so far so good. Content of 0x3049d2420 is 1476211373
// 479 : so far so good. Content of 0x3049d2424 is 805972220
// 480 : so far so good. Content of 0x3049d2428 is 1795739911
// 481 : so far so good. Content of 0x3049d242c is 265509239
// 482 : so far so good. Content of 0x3049d2430 is 2090245054
// 483 : so far so good. Content of 0x3049d2434 is 63641305
// 484 : so far so good. Content of 0x3049d2438 is 172556929
// 485 : so far so good. Content of 0x3049d243c is 1061382253
// 486 : so far so good. Content of 0x3049d2440 is 1652354189
// 487 : so far so good. Content of 0x3049d2444 is 2005815166
// 488 : so far so good. Content of 0x3049d2448 is 537204356
// 489 : so far so good. Content of 0x3049d244c is 772359304
// 490 : so far so good. Content of 0x3049d2450 is 1651659860
// 491 : so far so good. Content of 0x3049d2454 is 1073645898
// 492 : so far so good. Content of 0x3049d2458 is 1609005592
// 493 : so far so good. Content of 0x3049d245c is 1442901720
// 494 : so far so good. Content of 0x3049d2460 is 1463866116
// 495 : so far so good. Content of 0x3049d2464 is 1625151580
// 496 : so far so good. Content of 0x3049d2468 is 78098867
// 497 : so far so good. Content of 0x3049d246c is 495149352
// 498 : so far so good. Content of 0x3049d2470 is 476026939
// 499 : so far so good. Content of 0x3049d2474 is 1208178698
// 500 : so far so good. Content of 0x3049d2478 is 1401494901
// 501 : so far so good. Content of 0x3049d247c is 1324160811
// 502 : so far so good. Content of 0x3049d2480 is 797716616
// 503 : so far so good. Content of 0x3049d2484 is 482756891
// 504 : so far so good. Content of 0x3049d2488 is 501848671
// 505 : so far so good. Content of 0x3049d248c is 1402331728
// 506 : so far so good. Content of 0x3049d2490 is 356326671
// 507 : so far so good. Content of 0x3049d2494 is 1597951661
// 508 : so far so good. Content of 0x3049d2498 is 343077045
// 509 : so far so good. Content of 0x3049d249c is 102303120
// 510 : so far so good. Content of 0x3049d24a0 is 1421620240
// 511 : so far so good. Content of 0x3049d24a4 is 268317158
// 512 : so far so good. Content of 0x3049d24a8 is 2038299453
// 513 : so far so good. Content of 0x3049d24ac is 1039769627
// 514 : so far so good. Content of 0x3049d24b0 is 1333685350
// 515 : so far so good. Content of 0x3049d24b4 is 1962853711
// 516 : so far so good. Content of 0x3049d24b8 is 38535563
// 517 : so far so good. Content of 0x3049d24bc is 1274629594
// 518 : so far so good. Content of 0x3049d24c0 is 1550207533
// 519 : so far so good. Content of 0x3049d24c4 is 1066401727
// 520 : so far so good. Content of 0x3049d24c8 is 115307827
// 521 : so far so good. Content of 0x3049d24cc is 948398795
// 522 : so far so good. Content of 0x3049d24d0 is 1114919531
// 523 : so far so good. Content of 0x3049d24d4 is 1657737442
// 524 : so far so good. Content of 0x3049d24d8 is 140351516
// 525 : so far so good. Content of 0x3049d24dc is 950885006
// 526 : so far so good. Content of 0x3049d24e0 is 2098478515
// 527 : so far so good. Content of 0x3049d24e4 is 1004466924
// 528 : so far so good. Content of 0x3049d24e8 is 706642601
// 529 : so far so good. Content of 0x3049d24ec is 957627097
// 530 : so far so good. Content of 0x3049d24f0 is 1596168661
// 531 : so far so good. Content of 0x3049d24f4 is 440967103
// 532 : so far so good. Content of 0x3049d24f8 is 368034324
// 533 : so far so good. Content of 0x3049d24fc is 799980108
// 534 : so far so good. Content of 0x3049d2500 is 2018044936
// 535 : so far so good. Content of 0x3049d2504 is 2072002281
// 536 : so far so good. Content of 0x3049d2508 is 547517015
// 537 : so far so good. Content of 0x3049d250c is 151043710
// 538 : so far so good. Content of 0x3049d2510 is 265963216
// 539 : so far so good. Content of 0x3049d2514 is 1130301905
// 540 : so far so good. Content of 0x3049d2518 is 343775973
// 541 : so far so good. Content of 0x3049d251c is 1111767781
// 542 : so far so good. Content of 0x3049d2520 is 225882720
// 543 : so far so good. Content of 0x3049d2524 is 1807270791
// 544 : so far so good. Content of 0x3049d2528 is 791481169
// 545 : so far so good. Content of 0x3049d252c is 910297865
// 546 : so far so good. Content of 0x3049d2530 is 702715827
// 547 : so far so good. Content of 0x3049d2534 is 1532329536
// 548 : so far so good. Content of 0x3049d2538 is 1238616728
// 549 : so far so good. Content of 0x3049d253c is 1872357125
// 550 : so far so good. Content of 0x3049d2540 is 1628320384
// 551 : so far so good. Content of 0x3049d2544 is 1796580167
// 552 : so far so good. Content of 0x3049d2548 is 1502789949
// 553 : so far so good. Content of 0x3049d254c is 835500476
// 554 : so far so good. Content of 0x3049d2550 is 2008416046
// 555 : so far so good. Content of 0x3049d2554 is 1300521576
// 556 : so far so good. Content of 0x3049d2558 is 777568666
// 557 : so far so good. Content of 0x3049d255c is 1158577467
// 558 : so far so good. Content of 0x3049d2560 is 977260520
// 559 : so far so good. Content of 0x3049d2564 is 862627384
// 560 : so far so good. Content of 0x3049d2568 is 516341991
// 561 : so far so good. Content of 0x3049d256c is 178425210
// 562 : so far so good. Content of 0x3049d2570 is 905333258
// 563 : so far so good. Content of 0x3049d2574 is 1014428211
// 564 : so far so good. Content of 0x3049d2578 is 622268744
// 565 : so far so good. Content of 0x3049d257c is 225419518
// 566 : so far so good. Content of 0x3049d2580 is 464685718
// 567 : so far so good. Content of 0x3049d2584 is 1722321934
// 568 : so far so good. Content of 0x3049d2588 is 1132666825
// 569 : so far so good. Content of 0x3049d258c is 1436280767
// 570 : so far so good. Content of 0x3049d2590 is 1854658689
// 571 : so far so good. Content of 0x3049d2594 is 523449818
// 572 : so far so good. Content of 0x3049d2598 is 1528073014
// 573 : so far so good. Content of 0x3049d259c is 566211825
// 574 : so far so good. Content of 0x3049d25a0 is 822102918
// 575 : so far so good. Content of 0x3049d25a4 is 173958028
// 576 : so far so good. Content of 0x3049d25a8 is 987333029
// 577 : so far so good. Content of 0x3049d25ac is 500078034
// 578 : so far so good. Content of 0x3049d25b0 is 1708006727
// 579 : so far so good. Content of 0x3049d25b4 is 1055151240
// 580 : so far so good. Content of 0x3049d25b8 is 6933754
// 581 : so far so good. Content of 0x3049d25bc is 571486540
// 582 : so far so good. Content of 0x3049d25c0 is 1427408396
// 583 : so far so good. Content of 0x3049d25c4 is 913090935
// 584 : so far so good. Content of 0x3049d25c8 is 401203083
// 585 : so far so good. Content of 0x3049d25cc is 2069048048
// 586 : so far so good. Content of 0x3049d25d0 is 287846865
// 587 : so far so good. Content of 0x3049d25d4 is 1709087011
// 588 : so far so good. Content of 0x3049d25d8 is 2031615252
// 589 : so far so good. Content of 0x3049d25dc is 367553064
// 590 : so far so good. Content of 0x3049d25e0 is 1301377876
// 591 : so far so good. Content of 0x3049d25e4 is 137017237
// 592 : so far so good. Content of 0x3049d25e8 is 746232675
// 593 : so far so good. Content of 0x3049d25ec is 628070245
// 594 : so far so good. Content of 0x3049d25f0 is 1094482710
// 595 : so far so good. Content of 0x3049d25f4 is 1773470415
// 596 : so far so good. Content of 0x3049d25f8 is 1791728192
// 597 : so far so good. Content of 0x3049d25fc is 1560024710
// 598 : so far so good. Content of 0x3049d2600 is 707454747
// 599 : so far so good. Content of 0x3049d2604 is 1722463037
// 600 : so far so good. Content of 0x3049d2608 is 1356701299
// 601 : so far so good. Content of 0x3049d260c is 97368447
// 602 : so far so good. Content of 0x3049d2610 is 88949715
// 603 : so far so good. Content of 0x3049d2614 is 329241693
// 604 : so far so good. Content of 0x3049d2618 is 1647259579
// 605 : so far so good. Content of 0x3049d261c is 132567129
// 606 : so far so good. Content of 0x3049d2620 is 1115195164
// 607 : so far so good. Content of 0x3049d2624 is 1995333979
// 608 : so far so good. Content of 0x3049d2628 is 473553501
// 609 : so far so good. Content of 0x3049d262c is 439295525
// 610 : so far so good. Content of 0x3049d2630 is 191110289
// 611 : so far so good. Content of 0x3049d2634 is 1502574958
// 612 : so far so good. Content of 0x3049d2638 is 1517114033
// 613 : so far so good. Content of 0x3049d263c is 1062211800
// 614 : so far so good. Content of 0x3049d2640 is 562165089
// 615 : so far so good. Content of 0x3049d2644 is 1528087670
// 616 : so far so good. Content of 0x3049d2648 is 812535217
// 617 : so far so good. Content of 0x3049d264c is 430880846
// 618 : so far so good. Content of 0x3049d2650 is 499521038
// 619 : so far so good. Content of 0x3049d2654 is 936509543
// 620 : so far so good. Content of 0x3049d2658 is 1008240338
// 621 : so far so good. Content of 0x3049d265c is 1849385936
// 622 : so far so good. Content of 0x3049d2660 is 2098603321
// 623 : so far so good. Content of 0x3049d2664 is 954597719
// 624 : so far so good. Content of 0x3049d2668 is 73536496
// 625 : so far so good. Content of 0x3049d266c is 1124791247
// 626 : so far so good. Content of 0x3049d2670 is 67943788
// 627 : so far so good. Content of 0x3049d2674 is 1617428359
// 628 : so far so good. Content of 0x3049d2678 is 1270425987
// 629 : so far so good. Content of 0x3049d267c is 1767145035
// 630 : so far so good. Content of 0x3049d2680 is 707765235
// 631 : so far so good. Content of 0x3049d2684 is 498383912
// 632 : so far so good. Content of 0x3049d2688 is 1152185684
// 633 : so far so good. Content of 0x3049d268c is 924745989
// 634 : so far so good. Content of 0x3049d2690 is 866683784
// 635 : so far so good. Content of 0x3049d2694 is 2120263734
// 636 : so far so good. Content of 0x3049d2698 is 2076422667
// 637 : so far so good. Content of 0x3049d269c is 1826500519
// 638 : so far so good. Content of 0x3049d26a0 is 1862972615
// 639 : so far so good. Content of 0x3049d26a4 is 669167045
// 640 : so far so good. Content of 0x3049d26a8 is 318665976
// 641 : so far so good. Content of 0x3049d26ac is 2142326661
// 642 : so far so good. Content of 0x3049d26b0 is 1373365825
// 643 : so far so good. Content of 0x3049d26b4 is 1005182819
// 644 : so far so good. Content of 0x3049d26b8 is 2001271631
// 645 : so far so good. Content of 0x3049d26bc is 1483422903
// 646 : so far so good. Content of 0x3049d26c0 is 1751072698
// 647 : so far so good. Content of 0x3049d26c4 is 1162936798
// 648 : so far so good. Content of 0x3049d26c8 is 1230092639
// 649 : so far so good. Content of 0x3049d26cc is 341914004
// 650 : so far so good. Content of 0x3049d26d0 is 2029909503
// 651 : so far so good. Content of 0x3049d26d4 is 1763800679
// 652 : so far so good. Content of 0x3049d26d8 is 333748765
// 653 : so far so good. Content of 0x3049d26dc is 88207391
// 654 : so far so good. Content of 0x3049d26e0 is 737904107
// 655 : so far so good. Content of 0x3049d26e4 is 236264924
// 656 : so far so good. Content of 0x3049d26e8 is 207314365
// 657 : so far so good. Content of 0x3049d26ec is 1114057121
// 658 : so far so good. Content of 0x3049d26f0 is 48114454
// 659 : so far so good. Content of 0x3049d26f4 is 1205777106
// 660 : so far so good. Content of 0x3049d26f8 is 1840127450
// 661 : so far so good. Content of 0x3049d26fc is 1110051703
// 662 : so far so good. Content of 0x3049d2700 is 1448530832
// 663 : so far so good. Content of 0x3049d2704 is 1583071032
// 664 : so far so good. Content of 0x3049d2708 is 1499932141
// 665 : so far so good. Content of 0x3049d270c is 48961654
// 666 : so far so good. Content of 0x3049d2710 is 412281977
// 667 : so far so good. Content of 0x3049d2714 is 1440942217
// 668 : so far so good. Content of 0x3049d2718 is 742753900
// 669 : so far so good. Content of 0x3049d271c is 142357289
// 670 : so far so good. Content of 0x3049d2720 is 302173465
// 671 : so far so good. Content of 0x3049d2724 is 1978084747
// 672 : so far so good. Content of 0x3049d2728 is 476003622
// 673 : so far so good. Content of 0x3049d272c is 816289879
// 674 : so far so good. Content of 0x3049d2730 is 1258459317
// 675 : so far so good. Content of 0x3049d2734 is 359301516
// 676 : so far so good. Content of 0x3049d2738 is 56564048
// 677 : so far so good. Content of 0x3049d273c is 1484182762
// 678 : so far so good. Content of 0x3049d2740 is 1637121029
// 679 : so far so good. Content of 0x3049d2744 is 1532649039
// 680 : so far so good. Content of 0x3049d2748 is 166052708
// 681 : so far so good. Content of 0x3049d274c is 1266605903
// 682 : so far so good. Content of 0x3049d2750 is 1987502657
// 683 : so far so good. Content of 0x3049d2754 is 1996510761
// 684 : so far so good. Content of 0x3049d2758 is 924375752
// 685 : so far so good. Content of 0x3049d275c is 1086561466
// 686 : so far so good. Content of 0x3049d2760 is 1785108621
// 687 : so far so good. Content of 0x3049d2764 is 1974044557
// 688 : so far so good. Content of 0x3049d2768 is 1292006996
// 689 : so far so good. Content of 0x3049d276c is 1554426955
// 690 : so far so good. Content of 0x3049d2770 is 1115266930
// 691 : so far so good. Content of 0x3049d2774 is 1054021494
// 692 : so far so good. Content of 0x3049d2778 is 346645555
// 693 : so far so good. Content of 0x3049d277c is 2096192221
// 694 : so far so good. Content of 0x3049d2780 is 1233429312
// 695 : so far so good. Content of 0x3049d2784 is 586802293
// 696 : so far so good. Content of 0x3049d2788 is 1141231427
// 697 : so far so good. Content of 0x3049d278c is 1500142232
// 698 : so far so good. Content of 0x3049d2790 is 1432477444
// 699 : so far so good. Content of 0x3049d2794 is 209234791
// 700 : so far so good. Content of 0x3049d2798 is 1178402198
// 701 : so far so good. Content of 0x3049d279c is 1311549152
// 702 : so far so good. Content of 0x3049d27a0 is 1434444856
// 703 : so far so good. Content of 0x3049d27a4 is 1063273570
// 704 : so far so good. Content of 0x3049d27a8 is 1227464303
// 705 : so far so good. Content of 0x3049d27ac is 1264627439
// 706 : so far so good. Content of 0x3049d27b0 is 947712914
// 707 : so far so good. Content of 0x3049d27b4 is 324735799
// 708 : so far so good. Content of 0x3049d27b8 is 1078626766
// 709 : so far so good. Content of 0x3049d27bc is 1570591835
// 710 : so far so good. Content of 0x3049d27c0 is 67981921
// 711 : so far so good. Content of 0x3049d27c4 is 110846043
// 712 : so far so good. Content of 0x3049d27c8 is 1121122752
// 713 : so far so good. Content of 0x3049d27cc is 688574086
// 714 : so far so good. Content of 0x3049d27d0 is 75289719
// 715 : so far so good. Content of 0x3049d27d4 is 526439150
// 716 : so far so good. Content of 0x3049d27d8 is 230168410
// 717 : so far so good. Content of 0x3049d27dc is 822418623
// 718 : so far so good. Content of 0x3049d27e0 is 1185044669
// 719 : so far so good. Content of 0x3049d27e4 is 1282409605
// 720 : so far so good. Content of 0x3049d27e8 is 1312349943
// 721 : so far so good. Content of 0x3049d27ec is 2008437311
// 722 : so far so good. Content of 0x3049d27f0 is 1657922431
// 723 : so far so good. Content of 0x3049d27f4 is 1101977992
// 724 : so far so good. Content of 0x3049d27f8 is 1045139816
// 725 : so far so good. Content of 0x3049d27fc is 1396138699
// 726 : so far so good. Content of 0x3049d2800 is 1496786971
// 727 : so far so good. Content of 0x3049d2804 is 875180639
// 728 : so far so good. Content of 0x3049d2808 is 1045501370
// 729 : so far so good. Content of 0x3049d280c is 1030325836
// 730 : so far so good. Content of 0x3049d2810 is 1525679891
// 731 : so far so good. Content of 0x3049d2814 is 1147182857
// 732 : so far so good. Content of 0x3049d2818 is 594094833
// 733 : so far so good. Content of 0x3049d281c is 1300383328
// 734 : so far so good. Content of 0x3049d2820 is 601518177
// 735 : so far so good. Content of 0x3049d2824 is 1510474410
// 736 : so far so good. Content of 0x3049d2828 is 1139217683
// 737 : so far so good. Content of 0x3049d282c is 2014885176
// 738 : so far so good. Content of 0x3049d2830 is 505523489
// 739 : so far so good. Content of 0x3049d2834 is 887972091
// 740 : so far so good. Content of 0x3049d2838 is 1283070434
// 741 : so far so good. Content of 0x3049d283c is 1681484711
// 742 : so far so good. Content of 0x3049d2840 is 1976226904
// 743 : so far so good. Content of 0x3049d2844 is 1463491026
// 744 : so far so good. Content of 0x3049d2848 is 1763464891
// 745 : so far so good. Content of 0x3049d284c is 1132610790
// 746 : so far so good. Content of 0x3049d2850 is 494500522
// 747 : so far so good. Content of 0x3049d2854 is 308559364
// 748 : so far so good. Content of 0x3049d2858 is 1931706890
// 749 : so far so good. Content of 0x3049d285c is 539924884
// 750 : so far so good. Content of 0x3049d2860 is 1399116813
// 751 : so far so good. Content of 0x3049d2864 is 10341441
// 752 : so far so good. Content of 0x3049d2868 is 2009907127
// 753 : so far so good. Content of 0x3049d286c is 591316179
// 754 : so far so good. Content of 0x3049d2870 is 1844185784
// 755 : so far so good. Content of 0x3049d2874 is 598994537
// 756 : so far so good. Content of 0x3049d2878 is 2045329870
// 757 : so far so good. Content of 0x3049d287c is 1088387561
// 758 : so far so good. Content of 0x3049d2880 is 264032581
// 759 : so far so good. Content of 0x3049d2884 is 894374165
// 760 : so far so good. Content of 0x3049d2888 is 1508545802
// 761 : so far so good. Content of 0x3049d288c is 937357732
// 762 : so far so good. Content of 0x3049d2890 is 231367332
// 763 : so far so good. Content of 0x3049d2894 is 1645347854
// 764 : so far so good. Content of 0x3049d2898 is 214459759
// 765 : so far so good. Content of 0x3049d289c is 947609847
// 766 : so far so good. Content of 0x3049d28a0 is 739972377
// 767 : so far so good. Content of 0x3049d28a4 is 637940462
// 768 : so far so good. Content of 0x3049d28a8 is 1626979010
// 769 : so far so good. Content of 0x3049d28ac is 726943819
// 770 : so far so good. Content of 0x3049d28b0 is 710298150
// 771 : so far so good. Content of 0x3049d28b4 is 119413377
// 772 : so far so good. Content of 0x3049d28b8 is 1230900941
// 773 : so far so good. Content of 0x3049d28bc is 1042143836
// 774 : so far so good. Content of 0x3049d28c0 is 434826720
// 775 : so far so good. Content of 0x3049d28c4 is 245832299
// 776 : so far so good. Content of 0x3049d28c8 is 2092396112
// 777 : so far so good. Content of 0x3049d28cc is 1856734759
// 778 : so far so good. Content of 0x3049d28d0 is 1056219956
// 779 : so far so good. Content of 0x3049d28d4 is 788974390
// 780 : so far so good. Content of 0x3049d28d8 is 1728536152
// 781 : so far so good. Content of 0x3049d28dc is 348330048
// 782 : so far so good. Content of 0x3049d28e0 is 342695014
// 783 : so far so good. Content of 0x3049d28e4 is 123959044
// 784 : so far so good. Content of 0x3049d28e8 is 320514918
// 785 : so far so good. Content of 0x3049d28ec is 1005240150
// 786 : so far so good. Content of 0x3049d28f0 is 817350101
// 787 : so far so good. Content of 0x3049d28f4 is 1897741295
// 788 : so far so good. Content of 0x3049d28f8 is 910819821
// 789 : so far so good. Content of 0x3049d28fc is 885295731
// 790 : so far so good. Content of 0x3049d2900 is 1398644501
// 791 : so far so good. Content of 0x3049d2904 is 662128245
// 792 : so far so good. Content of 0x3049d2908 is 129154961
// 793 : so far so good. Content of 0x3049d290c is 1748946057
// 794 : so far so good. Content of 0x3049d2910 is 1927703510
// 795 : so far so good. Content of 0x3049d2914 is 1974593928
// 796 : so far so good. Content of 0x3049d2918 is 1935350805
// 797 : so far so good. Content of 0x3049d291c is 1653662173
// 798 : so far so good. Content of 0x3049d2920 is 366782137
// 799 : so far so good. Content of 0x3049d2924 is 1229309669
// 800 : so far so good. Content of 0x3049d2928 is 67439096
// 801 : so far so good. Content of 0x3049d292c is 1725004503
// 802 : so far so good. Content of 0x3049d2930 is 1121447421
// 803 : so far so good. Content of 0x3049d2934 is 1850318675
// 804 : so far so good. Content of 0x3049d2938 is 595278518
// 805 : so far so good. Content of 0x3049d293c is 1867224300
// 806 : so far so good. Content of 0x3049d2940 is 1260276489
// 807 : so far so good. Content of 0x3049d2944 is 835740262
// 808 : so far so good. Content of 0x3049d2948 is 1743532054
// 809 : so far so good. Content of 0x3049d294c is 1128868263
// 810 : so far so good. Content of 0x3049d2950 is 2018358643
// 811 : so far so good. Content of 0x3049d2954 is 902024889
// 812 : so far so good. Content of 0x3049d2958 is 1245245250
// 813 : so far so good. Content of 0x3049d295c is 1608776735
// 814 : so far so good. Content of 0x3049d2960 is 1891469415
// 815 : so far so good. Content of 0x3049d2964 is 726031364
// 816 : so far so good. Content of 0x3049d2968 is 407052494
// 817 : so far so good. Content of 0x3049d296c is 1595850963
// 818 : so far so good. Content of 0x3049d2970 is 1543867758
// 819 : so far so good. Content of 0x3049d2974 is 1887985652
// 820 : so far so good. Content of 0x3049d2978 is 156485092
// 821 : so far so good. Content of 0x3049d297c is 1524957316
// 822 : so far so good. Content of 0x3049d2980 is 1887766714
// ...
// 970 : so far so good. Content of 0x3049d2bd0 is 418069684
// 971 : so far so good. Content of 0x3049d2bd4 is 2078169651
// 972 : so far so good. Content of 0x3049d2bd8 is 1123289549
// 973 : so far so good. Content of 0x3049d2bdc is 598709266
// 974 : so far so good. Content of 0x3049d2be0 is 1545747467
// 975 : so far so good. Content of 0x3049d2be4 is 1268000110
// 976 : so far so good. Content of 0x3049d2be8 is 1797619589
// 977 : so far so good. Content of 0x3049d2bec is 1792486327
// 978 : so far so good. Content of 0x3049d2bf0 is 1417097773
// 979 : so far so good. Content of 0x3049d2bf4 is 1568625581
// 980 : so far so good. Content of 0x3049d2bf8 is 1380889295
// 981 : so far so good. Content of 0x3049d2bfc is 750607936
// 982 : so far so good. Content of 0x3049d2c00 is 1148637874
// 983 : so far so good. Content of 0x3049d2c04 is 1426245435
// 984 : so far so good. Content of 0x3049d2c08 is 694558231
// 985 : so far so good. Content of 0x3049d2c0c is 1866566972
// 986 : so far so good. Content of 0x3049d2c10 is 949983028
// 987 : so far so good. Content of 0x3049d2c14 is 1971319798
// 988 : so far so good. Content of 0x3049d2c18 is 594139070
// 989 : so far so good. Content of 0x3049d2c1c is 2043874587
// 990 : so far so good. Content of 0x3049d2c20 is 251766297
// 991 : so far so good. Content of 0x3049d2c24 is 893369089
// 992 : so far so good. Content of 0x3049d2c28 is 1796102646
// 993 : so far so good. Content of 0x3049d2c2c is 2067029090
// 994 : so far so good. Content of 0x3049d2c30 is 714958111
// 995 : so far so good. Content of 0x3049d2c34 is 1129966612
// 996 : so far so good. Content of 0x3049d2c38 is 1150957463
// 997 : so far so good. Content of 0x3049d2c3c is 1756872112
// 998 : so far so good. Content of 0x3049d2c40 is 1996923781
// 999 : so far so good. Content of 0x3049d2c44 is 1423551951
// 1000 : so far so good. Content of 0x3049d2c48 is 522329230
// 1001 : so far so good. Content of 0x3049d2c4c is 2021703321
// 1002 : so far so good. Content of 0x3049d2c50 is 1281453213
// 1003 : so far so good. Content of 0x3049d2c54 is 270655128
// 1004 : so far so good. Content of 0x3049d2c58 is 530371950
// 1005 : so far so good. Content of 0x3049d2c5c is 1904228600
// 1006 : so far so good. Content of 0x3049d2c60 is 421288959
// 1007 : so far so good. Content of 0x3049d2c64 is 349949754
// 1008 : so far so good. Content of 0x3049d2c68 is 1795289992
// 1009 : so far so good. Content of 0x3049d2c6c is 1293655194
// 1010 : so far so good. Content of 0x3049d2c70 is 1338403330
// 1011 : so far so good. Content of 0x3049d2c74 is 1801048632
// 1012 : so far so good. Content of 0x3049d2c78 is 1442353559
// 1013 : so far so good. Content of 0x3049d2c7c is 840858777
// 1014 : so far so good. Content of 0x3049d2c80 is 1871067779
// 1015 : so far so good. Content of 0x3049d2c84 is 1433118632
// 1016 : so far so good. Content of 0x3049d2c88 is 248263272
// 1017 : so far so good. Content of 0x3049d2c8c is 86383
// 1018 : so far so good. Content of 0x3049d2c90 is 1451839081
// 1019 : so far so good. Content of 0x3049d2c94 is 1350237153
// 1020 : so far so good. Content of 0x3049d2c98 is 976132622
// 1021 : so far so good. Content of 0x3049d2c9c is 1233398521
// 1022 : so far so good. Content of 0x3049d2ca0 is 69297956
// 1023 : so far so good. Content of 0x3049d2ca4 is 754609818
// 1024 : so far so good. Content of 0x3049d2ca8 is 1836275591
// 1025 : so far so good. Content of 0x3049d2cac is 796366900
// 1026 : so far so good. Content of 0x3049d2cb0 is 1420400196
// 1027 : so far so good. Content of 0x3049d2cb4 is 1237874120
// 1028 : so far so good. Content of 0x3049d2cb8 is 128762704
// 1029 : so far so good. Content of 0x3049d2cbc is 1598733599
// 1030 : so far so good. Content of 0x3049d2cc0 is 600207129
// 1031 : so far so good. Content of 0x3049d2cc4 is 950527144
// 1032 : so far so good. Content of 0x3049d2cc8 is 378859175
// 1033 : so far so good. Content of 0x3049d2ccc is 197140870
// 1034 : so far so good. Content of 0x3049d2cd0 is 1926818416
// 1035 : so far so good. Content of 0x3049d2cd4 is 2131204599
// 1036 : so far so good. Content of 0x3049d2cd8 is 1275947080
// 1037 : so far so good. Content of 0x3049d2cdc is 70874618
// 1038 : so far so good. Content of 0x3049d2ce0 is 1483764288
// 1039 : so far so good. Content of 0x3049d2ce4 is 1046279452
// 1040 : so far so good. Content of 0x3049d2ce8 is 1222648128
// 1041 : so far so good. Content of 0x3049d2cec is 1923552800
// 1042 : so far so good. Content of 0x3049d2cf0 is 933087662
// 1043 : so far so good. Content of 0x3049d2cf4 is 1478744840
// 1044 : so far so good. Content of 0x3049d2cf8 is 436279149
// 1045 : so far so good. Content of 0x3049d2cfc is 1034486385
// 1046 : so far so good. Content of 0x3049d2d00 is 585066583
// 1047 : so far so good. Content of 0x3049d2d04 is 2033924515
// 1048 : so far so good. Content of 0x3049d2d08 is 524630659
// 1049 : so far so good. Content of 0x3049d2d0c is 2047114878
// 1050 : so far so good. Content of 0x3049d2d10 is 1024245959
// 1051 : so far so good. Content of 0x3049d2d14 is 272918561
// 1052 : so far so good. Content of 0x3049d2d18 is 2064668382
// 1053 : so far so good. Content of 0x3049d2d1c is 1840728048
// 1054 : so far so good. Content of 0x3049d2d20 is 466884054
// 1055 : so far so good. Content of 0x3049d2d24 is 15049440
// 1056 : so far so good. Content of 0x3049d2d28 is 1680351381
// 1057 : so far so good. Content of 0x3049d2d2c is 108218770
// 1058 : so far so good. Content of 0x3049d2d30 is 2061702028
// 1059 : so far so good. Content of 0x3049d2d34 is 1377340251
// 1060 : so far so good. Content of 0x3049d2d38 is 1231367544
// 1061 : so far so good. Content of 0x3049d2d3c is 294405869
// 1062 : so far so good. Content of 0x3049d2d40 is 277117595
// 1063 : so far so good. Content of 0x3049d2d44 is 1770872469
// 1064 : so far so good. Content of 0x3049d2d48 is 1077722710
// 1065 : so far so good. Content of 0x3049d2d4c is 1408508172
// 1066 : so far so good. Content of 0x3049d2d50 is 1084605923
// 1067 : so far so good. Content of 0x3049d2d54 is 1130552125
// 1068 : so far so good. Content of 0x3049d2d58 is 254256219
// 1069 : so far so good. Content of 0x3049d2d5c is 1939298850
// 1070 : so far so good. Content of 0x3049d2d60 is 1436461431
// 1071 : so far so good. Content of 0x3049d2d64 is 596111243
// 1072 : so far so good. Content of 0x3049d2d68 is 830447846
// 1073 : so far so good. Content of 0x3049d2d6c is 840725869
// 1074 : so far so good. Content of 0x3049d2d70 is 1784766670
// 1075 : so far so good. Content of 0x3049d2d74 is 521841394
// 1076 : so far so good. Content of 0x3049d2d78 is 265094610
// 1077 : so far so good. Content of 0x3049d2d7c is 1564026392
// 1078 : so far so good. Content of 0x3049d2d80 is 1391731064
// 1079 : so far so good. Content of 0x3049d2d84 is 432109524
// 1080 : so far so good. Content of 0x3049d2d88 is 1822559361
// 1081 : so far so good. Content of 0x3049d2d8c is 48439519
// 1082 : so far so good. Content of 0x3049d2d90 is 226693620
// 1083 : so far so good. Content of 0x3049d2d94 is 403681562
// 1084 : so far so good. Content of 0x3049d2d98 is 775171661
// 1085 : so far so good. Content of 0x3049d2d9c is 1674303725
// 1086 : so far so good. Content of 0x3049d2da0 is 1544479434
// 1087 : so far so good. Content of 0x3049d2da4 is 1431005949
// 1088 : so far so good. Content of 0x3049d2da8 is 1247622090
// 1089 : so far so good. Content of 0x3049d2dac is 754137322
// 1090 : so far so good. Content of 0x3049d2db0 is 337486260
// 1091 : so far so good. Content of 0x3049d2db4 is 627260093
// 1092 : so far so good. Content of 0x3049d2db8 is 363159928
// 1093 : so far so good. Content of 0x3049d2dbc is 480385122
// 1094 : so far so good. Content of 0x3049d2dc0 is 1441716381
// 1095 : so far so good. Content of 0x3049d2dc4 is 869226366
// 1096 : so far so good. Content of 0x3049d2dc8 is 1903766468
// 1097 : so far so good. Content of 0x3049d2dcc is 1244171023
// 1098 : so far so good. Content of 0x3049d2dd0 is 734112722
// 1099 : so far so good. Content of 0x3049d2dd4 is 938966639
// 1100 : so far so good. Content of 0x3049d2dd8 is 1502463517
// 1101 : so far so good. Content of 0x3049d2ddc is 1791608793
// 1102 : so far so good. Content of 0x3049d2de0 is 1700769364
// 1103 : so far so good. Content of 0x3049d2de4 is 1823359178
// 1104 : so far so good. Content of 0x3049d2de8 is 606061956
// 1105 : so far so good. Content of 0x3049d2dec is 568356771
// 1106 : so far so good. Content of 0x3049d2df0 is 364988341
// 1107 : so far so good. Content of 0x3049d2df4 is 1145751355
// 1108 : so far so good. Content of 0x3049d2df8 is 157160836
// 1109 : so far so good. Content of 0x3049d2dfc is 2144768489
// 1110 : so far so good. Content of 0x3049d2e00 is 1610979728
// 1111 : so far so good. Content of 0x3049d2e04 is 262467120
// 1112 : so far so good. Content of 0x3049d2e08 is 353474902
// 1113 : so far so good. Content of 0x3049d2e0c is 912910312
// 1114 : so far so good. Content of 0x3049d2e10 is 1660439616
// 1115 : so far so good. Content of 0x3049d2e14 is 458633347
// 1116 : so far so good. Content of 0x3049d2e18 is 931853946
// 1117 : so far so good. Content of 0x3049d2e1c is 71032851
// 1118 : so far so good. Content of 0x3049d2e20 is 1995702672
// 1119 : so far so good. Content of 0x3049d2e24 is 227725811
// 1120 : so far so good. Content of 0x3049d2e28 is 571846523
// 1121 : so far so good. Content of 0x3049d2e2c is 1035191736
// 1122 : so far so good. Content of 0x3049d2e30 is 1702482605
// 1123 : so far so good. Content of 0x3049d2e34 is 553029607
// 1124 : so far so good. Content of 0x3049d2e38 is 459380633
// 1125 : so far so good. Content of 0x3049d2e3c is 606587866
// 1126 : so far so good. Content of 0x3049d2e40 is 817391553
// 1127 : so far so good. Content of 0x3049d2e44 is 446941412
// 1128 : so far so good. Content of 0x3049d2e48 is 1993997925
// 1129 : so far so good. Content of 0x3049d2e4c is 1640814040
// 1130 : so far so good. Content of 0x3049d2e50 is 1324059153
// 1131 : so far so good. Content of 0x3049d2e54 is 1236634257
// 1132 : so far so good. Content of 0x3049d2e58 is 765221733
// 1133 : so far so good. Content of 0x3049d2e5c is 1949588295
// 1134 : so far so good. Content of 0x3049d2e60 is 424988139
// 1135 : so far so good. Content of 0x3049d2e64 is 245042251
// 1136 : so far so good. Content of 0x3049d2e68 is 1698961258
// 1137 : so far so good. Content of 0x3049d2e6c is 1499292694
// 1138 : so far so good. Content of 0x3049d2e70 is 39194160
// 1139 : so far so good. Content of 0x3049d2e74 is 1606251138
// 1140 : so far so good. Content of 0x3049d2e78 is 245949929
// 1141 : so far so good. Content of 0x3049d2e7c is 1921919875
// 1142 : so far so good. Content of 0x3049d2e80 is 1405804598
// 1143 : so far so good. Content of 0x3049d2e84 is 742794292
// 1144 : so far so good. Content of 0x3049d2e88 is 821225633
// 1145 : so far so good. Content of 0x3049d2e8c is 461814562
// 1146 : so far so good. Content of 0x3049d2e90 is 711443276
// 1147 : so far so good. Content of 0x3049d2e94 is 38193236
// 1148 : so far so good. Content of 0x3049d2e98 is 1963590646
// 1149 : so far so good. Content of 0x3049d2e9c is 1686783873
// 1150 : so far so good. Content of 0x3049d2ea0 is 844929464
// 1151 : so far so good. Content of 0x3049d2ea4 is 1567627484
// 1152 : so far so good. Content of 0x3049d2ea8 is 1785742192
// 1153 : so far so good. Content of 0x3049d2eac is 1885054119
// 1154 : so far so good. Content of 0x3049d2eb0 is 278333842
// 1155 : so far so good. Content of 0x3049d2eb4 is 737499328
// 1156 : so far so good. Content of 0x3049d2eb8 is 2023078859
// 1157 : so far so good. Content of 0x3049d2ebc is 777800262
// 1158 : so far so good. Content of 0x3049d2ec0 is 756044145
// 1159 : so far so good. Content of 0x3049d2ec4 is 173205716
// 1160 : so far so good. Content of 0x3049d2ec8 is 1228127127
// 1161 : so far so good. Content of 0x3049d2ecc is 1667292172
// 1162 : so far so good. Content of 0x3049d2ed0 is 1812908748
// 1163 : so far so good. Content of 0x3049d2ed4 is 1059344000
// 1164 : so far so good. Content of 0x3049d2ed8 is 1755174370
// 1165 : so far so good. Content of 0x3049d2edc is 1380261398
// 1166 : so far so good. Content of 0x3049d2ee0 is 934961292
// 1167 : so far so good. Content of 0x3049d2ee4 is 756589545
// 1168 : so far so good. Content of 0x3049d2ee8 is 749808928
// 1169 : so far so good. Content of 0x3049d2eec is 604612300
// 1170 : so far so good. Content of 0x3049d2ef0 is 1973792143
// 1171 : so far so good. Content of 0x3049d2ef4 is 1344652192
// 1172 : so far so good. Content of 0x3049d2ef8 is 1598973563
// 1173 : so far so good. Content of 0x3049d2efc is 338314783
// 1174 : so far so good. Content of 0x3049d2f00 is 1667344272
// 1175 : so far so good. Content of 0x3049d2f04 is 541069801
// 1176 : so far so good. Content of 0x3049d2f08 is 1314384009
// 1177 : so far so good. Content of 0x3049d2f0c is 1835246221
// 1178 : so far so good. Content of 0x3049d2f10 is 675614486
// 1179 : so far so good. Content of 0x3049d2f14 is 1306624513
// 1180 : so far so good. Content of 0x3049d2f18 is 270415769
// 1181 : so far so good. Content of 0x3049d2f1c is 802432531
// 1182 : so far so good. Content of 0x3049d2f20 is 286245357
// 1183 : so far so good. Content of 0x3049d2f24 is 562345819
// 1184 : so far so good. Content of 0x3049d2f28 is 270649486
// 1185 : so far so good. Content of 0x3049d2f2c is 435546856
// 1186 : so far so good. Content of 0x3049d2f30 is 1611739816
// 1187 : so far so good. Content of 0x3049d2f34 is 152364254
// 1188 : so far so good. Content of 0x3049d2f38 is 985509754
// 1189 : so far so good. Content of 0x3049d2f3c is 2068549814
// 1190 : so far so good. Content of 0x3049d2f40 is 503962615
// 1191 : so far so good. Content of 0x3049d2f44 is 424166537
// 1192 : so far so good. Content of 0x3049d2f48 is 1468762966
// 1193 : so far so good. Content of 0x3049d2f4c is 174647297
// 1194 : so far so good. Content of 0x3049d2f50 is 1834458877
// 1195 : so far so good. Content of 0x3049d2f54 is 327625760
// 1196 : so far so good. Content of 0x3049d2f58 is 258077412
// 1197 : so far so good. Content of 0x3049d2f5c is 1737580191
// 1198 : so far so good. Content of 0x3049d2f60 is 2027638231
// 1199 : so far so good. Content of 0x3049d2f64 is 97754174
// 1200 : so far so good. Content of 0x3049d2f68 is 129412463
// 1201 : so far so good. Content of 0x3049d2f6c is 1781814877
// 1202 : so far so good. Content of 0x3049d2f70 is 303180324
// 1203 : so far so good. Content of 0x3049d2f74 is 1720494784
// 1204 : so far so good. Content of 0x3049d2f78 is 488527833
// 1205 : so far so good. Content of 0x3049d2f7c is 857306750
// 1206 : so far so good. Content of 0x3049d2f80 is 1286759527
// 1207 : so far so good. Content of 0x3049d2f84 is 1407044999
// 1208 : so far so good. Content of 0x3049d2f88 is 115377429
// 1209 : so far so good. Content of 0x3049d2f8c is 2118199609
// 1210 : so far so good. Content of 0x3049d2f90 is 1744412144
// 1211 : so far so good. Content of 0x3049d2f94 is 888155364
// 1212 : so far so good. Content of 0x3049d2f98 is 68372451
// 1213 : so far so good. Content of 0x3049d2f9c is 232032812
// 1214 : so far so good. Content of 0x3049d2fa0 is 2092651979
// 1215 : so far so good. Content of 0x3049d2fa4 is 1862124134
// 1216 : so far so good. Content of 0x3049d2fa8 is 1441132407
// 1217 : so far so good. Content of 0x3049d2fac is 1791793583
// 1218 : so far so good. Content of 0x3049d2fb0 is 511567600
// 1219 : so far so good. Content of 0x3049d2fb4 is 1539614259
// 1220 : so far so good. Content of 0x3049d2fb8 is 1266388310
// 1221 : so far so good. Content of 0x3049d2fbc is 477900753
// 1222 : so far so good. Content of 0x3049d2fc0 is 489115891
// 1223 : so far so good. Content of 0x3049d2fc4 is 3379321
// 1224 : so far so good. Content of 0x3049d2fc8 is 961673225
// 1225 : so far so good. Content of 0x3049d2fcc is 879965253
// 1226 : so far so good. Content of 0x3049d2fd0 is 2003613929
// 1227 : so far so good. Content of 0x3049d2fd4 is 48236096
// 1228 : so far so good. Content of 0x3049d2fd8 is 1102730553
// 1229 : so far so good. Content of 0x3049d2fdc is 808530661
// 1230 : so far so good. Content of 0x3049d2fe0 is 1845784858
// 1231 : so far so good. Content of 0x3049d2fe4 is 1704827491
// 1232 : so far so good. Content of 0x3049d2fe8 is 1308822963
// 1233 : so far so good. Content of 0x3049d2fec is 712542920
// 1234 : so far so good. Content of 0x3049d2ff0 is 1340040768
// 1235 : so far so good. Content of 0x3049d2ff4 is 1404181687
// 1236 : so far so good. Content of 0x3049d2ff8 is 1383816526
// 1237 : so far so good. Content of 0x3049d2ffc is 556455472
// [C kernel] Executable exited with code -11

// %% [markdown]
// # Summary
//
// - Pointers
// - Pointer Assignment
// - Pointers as Arguments
// - Pointer Arithmetic
// - Pointers to Pointers
// - Dangers of Pointers
